# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("..")
from test_funcs import fips_lookup
import random
from datetime import date, datetime, timedelta
from pprint import pprint

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 300)

# %%
covid_data = pd.read_pickle("../data/nyt_enriched.pkl", compression="bz2")

# %%
covid_data
# Out:
#          fips       date  daily_cases  cumulative_cases  daily_deaths  \
# 0       01001 2020-03-24            1                 1             0
# 1       01001 2020-03-25            3                 4             0
# 2       01001 2020-03-26            2                 6             0
# 3       01001 2020-03-27            0                 6             0
# 4       01001 2020-03-28            0                 6             0
# ...       ...        ...          ...               ...           ...
# 533995  56045 2020-09-15            0                23             0
# 533996  56045 2020-09-16            0                23             0
# 533997  56045 2020-09-17            0                23             0
# 533998  56045 2020-09-18            0                23             0
# 533999  56045 2020-09-19            0                23             0
#
#         cumulative_deaths  population
# 0                       0       55869
# 1                       0       55869
# 2                       0       55869
# 3                       0       55869
# 4                       0       55869
# ...                   ...         ...
# 533995                  0        6927
# 533996                  0        6927
# 533997                  0        6927
# 533998                  0        6927
# 533999                  0        6927
#
# [534000 rows x 7 columns]

# %%
covid_data.dtypes
# Out:
# fips                         object
# date                 datetime64[ns]
# daily_cases                   int64
# cumulative_cases              int64
# daily_deaths                  int64
# cumulative_deaths             int64
# population                    int64
# dtype: object

# %%
covid_data["date"].min()
# Out:
# Timestamp('2020-01-21 00:00:00')

# %%
covid_data["date"].max()
# Out:
# Timestamp('2020-09-19 00:00:00')

# %%
# test for uniqueness of fips+date
total_rows = len(covid_data)
composite_key = covid_data["date"].astype("str") + covid_data["fips"]
unique_date_plus_fips = len(composite_key.unique())
assert total_rows == unique_date_plus_fips, \
f"Total rows ({total_rows}) and unique date+fips counts ({unique_date_plus_fips}) do not match"

# %%
# build out the list of valid dates in the file
start_date = datetime(2020, 1, 21)
t = date.today()
end_date = datetime(t.year, t.month, t.day) - timedelta(days=1)

valid_dates = []
curr_date = start_date
while curr_date <= end_date:
    valid_dates.append(curr_date)
    curr_date = curr_date + timedelta(days=1)

print(f"Start: {start_date}")
print(f"End  : {end_date}")
print(f"Min  : {min(valid_dates)}")
print(f"Max  : {max(valid_dates)}")
print(f"Count: {len(valid_dates)}")
# Out:
# Start: 2020-01-21 00:00:00
# End  : 2020-09-19 00:00:00
# Min  : 2020-01-21 00:00:00
# Max  : 2020-09-19 00:00:00
# Count: 243

# %%
# get unique set of fips codes that we can randomly select from
fips_codes = set(covid_data["fips"])

# %%
# generate 100 random combinations of fips code + date and perform the lookup
for f in random.sample(fips_codes, 100):
    d = random.choice(valid_dates)
    results = fips_lookup(f, d, covid_data)
    print(f"{f} {str(d)[:10]}")
    pprint(results)
    print()
# Out:
# 01057 2020-02-07
# {}
#
# 51087 2020-08-14
# {'cumulative_cases': 4042,
#  'cumulative_deaths': 187,
#  'daily_cases': 43,
#  'daily_deaths': 0,
#  'population': 330818}
#
# 40083 2020-03-31
# {'cumulative_cases': 4,
#  'cumulative_deaths': 0,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 48011}
#
# 51059 2020-03-01
# {}
#
# 48133 2020-04-29
# {'cumulative_cases': 3,
#  'cumulative_deaths': 0,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 18360}
#
# 26137 2020-08-16
# {'cumulative_cases': 146,
#  'cumulative_deaths': 11,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 24668}
#
# 13083 2020-03-06
# {}
#
# 20047 2020-04-15
# {}
#
# 26089 2020-08-25
# {'cumulative_cases': 84,
#  'cumulative_deaths': 1,
#  'daily_cases': 0,
#  'daily_deaths': 1,
#  'population': 21761}
#
# 39097 2020-08-19
# {'cumulative_cases': 605,
#  'cumulative_deaths': 11,
#  'daily_cases': 4,
#  'daily_deaths': 0,
#  'population': 44731}
#
# 28025 2020-08-03
# {'cumulative_cases': 370,
#  'cumulative_deaths': 13,
#  'daily_cases': 2,
#  'daily_deaths': -1,
#  'population': 19316}
#
# 48151 2020-05-01
# {}
#
# 28133 2020-09-04
# {'cumulative_cases': 1300,
#  'cumulative_deaths': 39,
#  'daily_cases': 9,
#  'daily_deaths': 0,
#  'population': 25110}
#
# 40079 2020-04-29
# {'cumulative_cases': 10,
#  'cumulative_deaths': 0,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 49853}
#
# 17001 2020-06-07
# {'cumulative_cases': 46,
#  'cumulative_deaths': 1,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 65435}
#
# 48123 2020-04-01
# {'cumulative_cases': 4,
#  'cumulative_deaths': 0,
#  'daily_cases': 1,
#  'daily_deaths': 0,
#  'population': 20160}
#
# 37115 2020-01-28
# {}
#
# 12071 2020-06-23
# {'cumulative_cases': 3744,
#  'cumulative_deaths': 149,
#  'daily_cases': 79,
#  'daily_deaths': 0,
#  'population': 770577}
#
# 39169 2020-07-31
# {'cumulative_cases': 485,
#  'cumulative_deaths': 58,
#  'daily_cases': 13,
#  'daily_deaths': 0,
#  'population': 115710}
#
# 37157 2020-04-12
# {'cumulative_cases': 14,
#  'cumulative_deaths': 2,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 91010}
#
# 18145 2020-01-28
# {}
#
# 39175 2020-05-12
# {'cumulative_cases': 27,
#  'cumulative_deaths': 2,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 21772}
#
# 35059 2020-08-01
# {'cumulative_cases': 28,
#  'cumulative_deaths': 0,
#  'daily_cases': 2,
#  'daily_deaths': 0,
#  'population': 4059}
#
# 29003 2020-04-06
# {}
#
# 13027 2020-03-01
# {}
#
# 45007 2020-04-22
# {'cumulative_cases': 135,
#  'cumulative_deaths': 5,
#  'daily_cases': 3,
#  'daily_deaths': 0,
#  'population': 202558}
#
# 40055 2020-08-31
# {'cumulative_cases': 88,
#  'cumulative_deaths': 8,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 5712}
#
# 21169 2020-06-30
# {'cumulative_cases': 9,
#  'cumulative_deaths': 2,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 10071}
#
# 05025 2020-06-28
# {'cumulative_cases': 25,
#  'cumulative_deaths': 0,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 7956}
#
# 26159 2020-02-27
# {}
#
# 38093 2020-02-17
# {}
#
# 35053 2020-01-27
# {}
#
# 18079 2020-08-22
# {'cumulative_cases': 247,
#  'cumulative_deaths': 14,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 27735}
#
# 42069 2020-01-24
# {}
#
# 47087 2020-05-02
# {'cumulative_cases': 7,
#  'cumulative_deaths': 0,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 11786}
#
# 46085 2020-01-23
# {}
#
# 29173 2020-02-11
# {}
#
# 21131 2020-01-21
# {}
#
# 55013 2020-08-10
# {'cumulative_cases': 22,
#  'cumulative_deaths': 1,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 15414}
#
# 20019 2020-07-07
# {'cumulative_cases': 4,
#  'cumulative_deaths': 0,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 3250}
#
# 42039 2020-08-13
# {'cumulative_cases': 161,
#  'cumulative_deaths': 1,
#  'daily_cases': -1,
#  'daily_deaths': 0,
#  'population': 84629}
#
# 10003 2020-08-15
# {'cumulative_cases': 7490,
#  'cumulative_deaths': 293,
#  'daily_cases': 40,
#  'daily_deaths': 0,
#  'population': 558753}
#
# 18121 2020-09-19
# {'cumulative_cases': 99,
#  'cumulative_deaths': 2,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 16937}
#
# 28157 2020-05-11
# {'cumulative_cases': 77,
#  'cumulative_deaths': 9,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 8630}
#
# 51195 2020-06-21
# {'cumulative_cases': 27,
#  'cumulative_deaths': 2,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 37383}
#
# 21129 2020-07-06
# {'cumulative_cases': 1,
#  'cumulative_deaths': 0,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 7403}
#
# 13017 2020-08-10
# {'cumulative_cases': 452,
#  'cumulative_deaths': 4,
#  'daily_cases': 16,
#  'daily_deaths': 0,
#  'population': 16700}
#
# 13191 2020-01-22
# {}
#
# 30067 2020-07-12
# {'cumulative_cases': 17,
#  'cumulative_deaths': 0,
#  'daily_cases': 1,
#  'daily_deaths': 0,
#  'population': 16606}
#
# 51620 2020-08-07
# {'cumulative_cases': 174,
#  'cumulative_deaths': 6,
#  'daily_cases': 16,
#  'daily_deaths': 0,
#  'population': 7967}
#
# 56043 2020-02-22
# {}
#
# 29213 2020-05-11
# {'cumulative_cases': 12,
#  'cumulative_deaths': 2,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 55928}
#
# 42107 2020-02-14
# {}
#
# 42019 2020-05-21
# {'cumulative_cases': 209,
#  'cumulative_deaths': 12,
#  'daily_cases': 1,
#  'daily_deaths': 0,
#  'population': 187853}
#
# 26025 2020-07-09
# {'cumulative_cases': 594,
#  'cumulative_deaths': 39,
#  'daily_cases': 11,
#  'daily_deaths': 0,
#  'population': 134159}
#
# 40063 2020-06-06
# {'cumulative_cases': 3,
#  'cumulative_deaths': 0,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 13279}
#
# 56009 2020-08-27
# {'cumulative_cases': 40,
#  'cumulative_deaths': 0,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 13822}
#
# 20115 2020-09-19
# {'cumulative_cases': 86,
#  'cumulative_deaths': 1,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 11884}
#
# 31075 2020-04-11
# {}
#
# 20203 2020-04-22
# {}
#
# 55037 2020-02-01
# {}
#
# 47069 2020-04-28
# {'cumulative_cases': 11,
#  'cumulative_deaths': 0,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 25050}
#
# 06023 2020-04-09
# {'cumulative_cases': 50,
#  'cumulative_deaths': 0,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 135558}
#
# 41007 2020-09-13
# {'cumulative_cases': 102,
#  'cumulative_deaths': 0,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 40224}
#
# 31067 2020-06-03
# {'cumulative_cases': 45,
#  'cumulative_deaths': 4,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 21513}
#
# 30033 2020-05-23
# {}
#
# 05085 2020-01-21
# {}
#
# 20163 2020-06-03
# {'cumulative_cases': 7,
#  'cumulative_deaths': 0,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 4920}
#
# 54049 2020-02-22
# {}
#
# 17129 2020-05-11
# {'cumulative_cases': 17,
#  'cumulative_deaths': 0,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 12196}
#
# 16073 2020-02-22
# {}
#
# 29047 2020-04-23
# {'cumulative_cases': 62,
#  'cumulative_deaths': 1,
#  'daily_cases': 1,
#  'daily_deaths': 0,
#  'population': 249948}
#
# 31141 2020-04-14
# {'cumulative_cases': 6,
#  'cumulative_deaths': 0,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 33470}
#
# 28021 2020-03-11
# {}
#
# 19161 2020-08-19
# {'cumulative_cases': 94,
#  'cumulative_deaths': 0,
#  'daily_cases': 3,
#  'daily_deaths': 0,
#  'population': 9721}
#
# 53001 2020-04-23
# {'cumulative_cases': 45,
#  'cumulative_deaths': 0,
#  'daily_cases': 1,
#  'daily_deaths': 0,
#  'population': 19983}
#
# 48339 2020-02-04
# {}
#
# 42023 2020-04-21
# {'cumulative_cases': 1,
#  'cumulative_deaths': 0,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 4447}
#
# 02013 2020-06-13
# {'cumulative_cases': 1,
#  'cumulative_deaths': 0,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 3337}
#
# 08103 2020-03-24
# {}
#
# 50005 2020-05-30
# {'cumulative_cases': 15,
#  'cumulative_deaths': 0,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 29993}
#
# 22015 2020-03-09
# {}
#
# 26009 2020-03-06
# {}
#
# 16051 2020-08-06
# {'cumulative_cases': 174,
#  'cumulative_deaths': 1,
#  'daily_cases': 10,
#  'daily_deaths': 0,
#  'population': 29871}
#
# 39151 2020-07-23
# {'cumulative_cases': 1449,
#  'cumulative_deaths': 122,
#  'daily_cases': 37,
#  'daily_deaths': 1,
#  'population': 370606}
#
# 13235 2020-05-28
# {'cumulative_cases': 40,
#  'cumulative_deaths': 2,
#  'daily_cases': 1,
#  'daily_deaths': 0,
#  'population': 11137}
#
# 48137 2020-04-14
# {}
#
# 50023 2020-01-29
# {}
#
# 12083 2020-03-05
# {}
#
# 33009 2020-05-26
# {'cumulative_cases': 69,
#  'cumulative_deaths': 1,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 89886}
#
# 05099 2020-03-23
# {}
#
# 08015 2020-02-02
# {}
#
# 39033 2020-08-09
# {'cumulative_cases': 174,
#  'cumulative_deaths': 5,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 41494}
#
# 22045 2020-05-30
# {'cumulative_cases': 407,
#  'cumulative_deaths': 37,
#  'daily_cases': 3,
#  'daily_deaths': 0,
#  'population': 69830}
# 33013 2020-07-03
# {'cumulative_cases': 417,
#  'cumulative_deaths': 18,
#  'daily_cases': 3,
#  'daily_deaths': 0,
#  'population': 151391}
#
# 08079 2020-04-15
# {'cumulative_cases': 2,
#  'cumulative_deaths': 0,
#  'daily_cases': 0,
#  'daily_deaths': 0,
#  'population': 769}
#
# 39163 2020-03-25
# {}
#
# 48001 2020-05-07
# {'cumulative_cases': 40,
#  'cumulative_deaths': 0,
#  'daily_cases': 2,
#  'daily_deaths': 0,
#  'population': 57735}
#
# 12039 2020-02-04
# {}
#
# 55097 2020-09-17
# {'cumulative_cases': 1071,
#  'cumulative_deaths': 3,
#  'daily_cases': 34,
#  'daily_deaths': 0,
#  'population': 70772}

# %%
# examine cook county
covid_data[covid_data["fips"] == "17031"]
# Out:
#          fips       date  daily_cases  cumulative_cases  daily_deaths  \
# 106747  17031 2020-01-24            1                 1             0
# 106748  17031 2020-01-25            0                 1             0
# 106749  17031 2020-01-26            0                 1             0
# 106750  17031 2020-01-27            0                 1             0
# 106751  17031 2020-01-28            0                 1             0
# 106752  17031 2020-01-29            0                 1             0
# 106753  17031 2020-01-30            1                 2             0
# 106754  17031 2020-01-31            0                 2             0
# 106755  17031 2020-02-01            0                 2             0
# 106756  17031 2020-02-02            0                 2             0
# 106757  17031 2020-02-03            0                 2             0
# 106758  17031 2020-02-04            0                 2             0
# 106759  17031 2020-02-05            0                 2             0
# 106760  17031 2020-02-06            0                 2             0
# 106761  17031 2020-02-07            0                 2             0
# 106762  17031 2020-02-08            0                 2             0
# 106763  17031 2020-02-09            0                 2             0
# 106764  17031 2020-02-10            0                 2             0
# 106765  17031 2020-02-11            0                 2             0
# 106766  17031 2020-02-12            0                 2             0
# 106767  17031 2020-02-13            0                 2             0
# 106768  17031 2020-02-14            0                 2             0
# 106769  17031 2020-02-15            0                 2             0
# 106770  17031 2020-02-16            0                 2             0
# 106771  17031 2020-02-17            0                 2             0
# 106772  17031 2020-02-18            0                 2             0
# 106773  17031 2020-02-19            0                 2             0
# 106774  17031 2020-02-20            0                 2             0
# 106775  17031 2020-02-21            0                 2             0
# 106776  17031 2020-02-22            0                 2             0
# 106777  17031 2020-02-23            0                 2             0
# 106764                  0     5150233
# 106765                  0     5150233
# 106766                  0     5150233
# 106767                  0     5150233
# 106768                  0     5150233
# 106769                  0     5150233
# 106770                  0     5150233
# 106771                  0     5150233
# 106772                  0     5150233
# 106773                  0     5150233
# 106774                  0     5150233
# 106775                  0     5150233
# 106776                  0     5150233
# 106777                  0     5150233
# 106778                  0     5150233
# 106779                  0     5150233
# 106780                  0     5150233
# 106781                  0     5150233
# 106782                  0     5150233
# 106783                  0     5150233
# 106784                  0     5150233
# 106785                  0     5150233
# 106786                  0     5150233
# 106787                  0     5150233
# 106788                  0     5150233
# 106789                  0     5150233
# 106790                  0     5150233
# 106791                  0     5150233
# 106792                  0     5150233
# 106793                  0     5150233
# 106794                  0     5150233
# 106795                  0     5150233
# 106796                  0     5150233
# 106797                  0     5150233
# 106798                  0     5150233
# 106799                  0     5150233
# 106800                  1     5150233
# 106801                  1     5150233
# 106802                  2     5150233
# 106803                  3     5150233
# 106804                  4     5150233
# 106805                  6     5150233
# 106806                  9     5150233
# 106807                 12     5150233
# 106808                 13     5150233
# 106809                 18     5150233
# 106810                 20     5150233
# 106811                 28     5150233
# 106812                 40     5150233
# 106813                 44     5150233
# 106814                 61     5150233
# 106815                 95     5150233
# 106816                107     5150233
# 106817                141     5150233
# 106818                167     5150233
# 106819                186     5150233
# 106820                209     5150233
# 106821                249     5150233
# 106822                312     5150233
# 106823                351     5150233
# 106824                398     5150233
# 106825                453     5150233
# 106826                485     5150233
# 106827                543     5150233
# 106828                577     5150233
# 106829                630     5150233
# 106830                722     5150233
# 106831                760     5150233
# 106832                860     5150233
# 106833                877     5150233
# 106834                915     5150233
# 106835               1002     5150233
# 106836               1072     5150233
# 106837               1142     5150233
# 106838               1220     5150233
# 106839               1267     5150233
# 106840               1313     5150233
# 106841               1347     5150233
# 106842               1457     5150233
# 106843               1516     5150233
# 106844               1607     5150233
# 106845               1673     5150233
# 106846               1743     5150233
# 106847               1786     5150233
# 106848               1802     5150233
# 106849               1922     5150233
# 106850               2004     5150233
# 106851               2110     5150233
# 106852               2197     5150233
# 106853               2264     5150233
# 106854               2317     5150233
# 106855               2361     5150233
# 106856               2449     5150233
# 106857               2589     5150233
# 106858               2675     5150233
# 106859               2762     5150233
# 106860               2814     5150233
# 106861               2839     5150233
# 106862               2889     5150233
# 106863               2980     5150233
# 106864               3074     5150233
# 106865               3114     5150233
# 106866               3187     5150233
# 106867               3246     5150233
# 106868               3304     5150233
# 106869               3324     5150233
# 106870               3354     5150233
# 106871               3455     5150233
# 106872               3519     5150233
# 106873               3570     5150233
# 106874               3603     5150233
# 106875               3642     5150233
# 106876               3658     5150233
# 106877               3726     5150233
# 106878               3780     5150233
# 106879               3846     5150233
# 106880               3880     5150233
# 106881               3913     5150233
# 106882               3944     5150233
# 106883               3959     5150233
# 106884               4010     5150233
# 106885               4053     5150233
# 106886               4111     5150233
# 106887               4162     5150233
# 106888               4173     5150233
# 106889               4189     5150233
# 106890               4206     5150233
# 106891               4253     5150233
# 106892               4304     5150233
# 106893               4333     5150233
# 106894               4363     5150233
# 106895               4390     5150233
# 106896               4404     5150233
# 106897               4423     5150233
# 106898               4439     5150233
# 106899               4478     5150233
# 106900               4500     5150233
# 106901               4526     5150233
# 106902               4536     5150233
# 106903               4542     5150233
# 106904               4554     5150233
# 106905               4565     5150233
# 106906               4581     5150233
# 106907               4609     5150233
# 106908               4618     5150233
# 106909               4622     5150233
# 106910               4627     5150233
# 106911               4630     5150233
# 106912               4651     5150233
# 106913               4664     5150233
# 106914               4676     5150233
# 106915               4693     5150233
# 106916               4711     5150233
# 106917               4725     5150233
# 106918               4729     5150233
# 106919               4741     5150233
# 106920               4745     5150233
# 106921               4750     5150233
# 106922               4765     5150233
# 106923               4774     5150233
# 106924               4776     5150233
# 106925               4777     5150233
# 106926               4788     5150233
# 106927               4801     5150233
# 106928               4810     5150233
# 106929               4822     5150233
# 106930               4829     5150233
# 106931               4830     5150233
# 106932               4845     5150233
# 106933               4857     5150233
# 106934               4864     5150233
# 106935               4872     5150233
# 106936               4886     5150233
# 106937               4888     5150233
# 106938               4894     5150233
# 106939               4897     5150233
# 106940               4902     5150233
# 106941               4909     5150233
# 106942               4912     5150233
# 106943               4920     5150233
# 106944               4924     5150233
# 106945               4928     5150233
# 106946               4928     5150233
# 106947               4933     5150233
# 106948               4934     5150233
# 106949               4943     5150233
# 106950               4951     5150233
# 106951               4953     5150233
# 106952               4962     5150233
# 106953               4964     5150233
# 106954               4974     5150233
# 106955               4984     5150233
# 106956               4988     5150233
# 106957               4997     5150233
# 106958               5008     5150233
# 106959               5013     5150233
# 106960               5015     5150233
# 106961               5022     5150233
# 106962               5031     5150233
# 106963               5039     5150233
# 106964               5045     5150233
# 106965               5046     5150233
# 106966               5054     5150233
# 106967               5058     5150233
# 106968               5069     5150233
# 106969               5073     5150233
# 106970               5080     5150233
# 106971               5086     5150233
# 106972               5092     5150233
# 106973               5094     5150233
# 106974               5097     5150233
# 106975               5098     5150233
# 106976               5100     5150233
# 106977               5103     5150233
# 106978               5113     5150233
# 106979               5128     5150233
# 106980               5133     5150233
# 106981               5134     5150233
# 106982               5137     5150233
# 106983               5146     5150233
# 106984               5147     5150233
# 106985               5150     5150233
# 106986               5157     5150233

# %%
# lookup cook county
# google "cook county covid counts" and scroll down a bit to find the numbers to validate against
f = "17031"
d = end_date
results = fips_lookup(f, d, covid_data)
print(f"{f} {str(d)[:10]}")
pprint(results)
print()
# Out:
# 17031 2020-09-19
# {'cumulative_cases': 138576,
#  'cumulative_deaths': 5157,
#  'daily_cases': 996,
#  'daily_deaths': 7,
#  'population': 5150233}

# %%
# lookup los angeles county
# google "los angeles county covid counts" and scroll down a bit to find the numbers to validate against
f = "06037"
d = end_date
results = fips_lookup(f, d, covid_data)
print(f"{f} {str(d)[:10]}")
pprint(results)
print()
# Out:
# 06037 2020-09-19
# {'cumulative_cases': 259817,
#  'cumulative_deaths': 6330,
#  'daily_cases': 1301,
#  'daily_deaths': 0,
#  'population': 10039107}

# %%
# lookup king county, washington
# google "king county covid counts" and scroll down a bit to find the numbers to validate against
f = "53033"
d = end_date
results = fips_lookup(f, d, covid_data)
print(f"{f} {str(d)[:10]}")
pprint(results)
print()
# Out:
# 53033 2020-09-19
# {'cumulative_cases': 21418,
#  'cumulative_deaths': 770,
#  'daily_cases': 95,
#  'daily_deaths': 0,
#  'population': 2252782}
